# %%
"""
Script 2: AutoRectifier

Description:
This script rectifies a batch of raster images (e.g., scanned and preprocessed micro-section drawings)
by applying a scale transformation based on a 1-meter vector scale stored in a shapefile. Each image is 
resized accordingly and georeferenced as a standalone GeoTIFF using a synthetic coordinate system with 
systematic offsets for spatial arrangement. No GCPs are required.

To use this script correctly, the user must define user settings (see below):

Notes:
- The script automatically calculates the scale factor and pixel resolution.
- Output rasters are saved as single-band (grayscale) GeoTIFFs with spatial referencing.
- Ensure the vector scale shapefile contains a valid LineString as its first geometry.

"""

import numpy as np
import cv2
from matplotlib import pyplot as plt
import geopandas as gpd
from shapely.geometry import LineString
import os
import time
import rasterio
from rasterio.transform import from_origin

# ---------------------------------------------
# USER SETTINGS (EDIT BEFORE RUNNING)
# ---------------------------------------------
input_folder = r"C:\path_to_input_folder"  # folder with input images
output_folder = r"C:\path_to_output_folder"  # folder for output GeoTIFFs
shapefile_path = r"C:\path_to_SCALE.shp"  # shapefile with vector scale (1m line)
crs = "EPSG:XXX"  # Coordinate Reference System to apply to all outputs
initial_upper_left_x = 0  # upper left X of first raster
initial_upper_left_y = 0  # upper left Y of first raster
offset = 1.5  # spacing in meters between rasters (used to calculate each position)
columns_per_row = 25  # how many rasters per row before moving to new line
image_scale_length_pixels = 744  # length of 1 meter scale bar in pixels on the image
real_world_length_meters = 1.000366  # length of the scale in meters (should match vector length)

# ---------------------------------------------
# FUNCTIONS
# ---------------------------------------------
def display(img, title=''):
    """Display a grayscale image with matplotlib."""
    plt.imshow(img, cmap='gray')
    plt.title(title)
    plt.axis('off')
    plt.show()

def get_line_length_from_shapefile(shapefile_path):
    """Extracts the length of the first LineString in a shapefile."""
    gdf = gpd.read_file(shapefile_path)
    line_geom = gdf.geometry.iloc[0]
    if isinstance(line_geom, LineString):
        return line_geom.length
    else:
        raise ValueError("Shapefile does not contain a LineString geometry.")

def calculate_scale_factor(vector_length_meters, image_scale_length_pixels, resolution_meters_per_pixel):
    """Calculates the scaling factor to apply to image based on vector length."""
    vector_length_pixels = vector_length_meters / resolution_meters_per_pixel
    scale_factor = image_scale_length_pixels / vector_length_pixels
    return scale_factor

def rectify_image_without_gcp(img, scale_factor):
    """Resizes the image based on a scale factor (no GCPs used)."""
    height, width = img.shape[:2]
    new_size = (int(width * scale_factor), int(height * scale_factor))
    resized_img = cv2.resize(img, new_size, interpolation=cv2.INTER_LINEAR)
    return resized_img

# ---------------------------------------------
# MAIN PROCESS
# ---------------------------------------------
start_time = time.time()

# Get scale from shapefile
meritko_length_meters = get_line_length_from_shapefile(shapefile_path)
print("Vector scale length (m):", meritko_length_meters)

# Calculate pixel resolution and scale factor
resolution_meters_per_pixel = real_world_length_meters / image_scale_length_pixels
print("Resolution (meters per pixel):", resolution_meters_per_pixel)

scale_factor = calculate_scale_factor(meritko_length_meters, image_scale_length_pixels, resolution_meters_per_pixel)
print("Scale factor:", scale_factor)

# Create output folder if needed
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Iterate over images
for i, filename in enumerate(os.listdir(input_folder)):
    if filename.lower().endswith((".png", ".jpg", ".jpeg")):
        input_path = os.path.join(input_folder, filename)
        img = cv2.imread(input_path, 0)
        print(f"Processing {filename} with original dimensions: {img.shape}")

        # Rescale image
        warped_img = rectify_image_without_gcp(img, scale_factor)
        print(f"Resized dimensions for {filename}: {warped_img.shape}")

        # Calculate upper-left coordinate for this raster
        col_number = i % columns_per_row
        row_number = i // columns_per_row
        upper_left_x = initial_upper_left_x + col_number * offset
        upper_left_y = initial_upper_left_y - row_number * offset
        print(f"Upper-left corner for {filename}: X = {upper_left_x}, Y = {upper_left_y}")

        # Create rasterio transform
        transform = from_origin(upper_left_x, upper_left_y, resolution_meters_per_pixel, resolution_meters_per_pixel)

        # Prepare image array for rasterio
        warped_array = np.expand_dims(warped_img, axis=0)  # shape (1, H, W)

        # Save to GeoTIFF
        geo_output_path = os.path.join(output_folder, filename.replace(".png", ".tif").replace(".jpg", ".tif"))
        try:
            with rasterio.open(
                geo_output_path, "w",
                driver="GTiff",
                height=warped_array.shape[1],
                width=warped_array.shape[2],
                count=1,
                dtype=warped_array.dtype,
                crs=crs,
                transform=transform
            ) as dst:
                dst.write(warped_array)
            print(f"GeoTIFF saved: {geo_output_path}")
        except Exception as e:
            print(f"Error writing {filename}: {e}")

# Report time
elapsed_time = time.time() - start_time
print(f"All images rectified in {elapsed_time:.2f} seconds.")
# Out:
# Vector scale length (m): 0.9992981185365547
# Resolution (meters per pixel): 0.0013445779569892474
# Scale factor: 1.0010686315160977
# Processing CS_10.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_10.jpg: (2340, 1654)
# Upper-left corner for CS_10.jpg: X = 0.0, Y = 0.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_10.tif
# Processing CS_100.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_100.jpg: (2340, 1654)
# Upper-left corner for CS_100.jpg: X = 1.5, Y = 0.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_100.tif
# Processing CS_1013.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_1013.jpg: (2340, 1654)
# Upper-left corner for CS_1013.jpg: X = 3.0, Y = 0.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_1013.tif
# Processing CS_1014.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_1014.jpg: (2340, 1654)
# Upper-left corner for CS_1014.jpg: X = 4.5, Y = 0.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_1014.tif
# Processing CS_1015.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_1015.jpg: (2340, 1654)
# Upper-left corner for CS_1015.jpg: X = 6.0, Y = 0.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_1015.tif
# Processing CS_1026.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_1026.jpg: (2340, 1654)
# Upper-left corner for CS_1026.jpg: X = 7.5, Y = 0.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_1026.tif
# Processing CS_1027.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_1027.jpg: (2340, 1654)
# Upper-left corner for CS_1027.jpg: X = 9.0, Y = 0.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_1027.tif
# Processing CS_1028.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_1028.jpg: (2340, 1654)
# Upper-left corner for CS_1028.jpg: X = 10.5, Y = 0.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_1028.tif
# Processing CS_103.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_103.jpg: (2340, 1654)
# Upper-left corner for CS_103.jpg: X = 12.0, Y = 0.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_103.tif
# Processing CS_104.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_104.jpg: (2340, 1654)
# Upper-left corner for CS_104.jpg: X = 13.5, Y = 0.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_104.tif
# Processing CS_1040.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_1040.jpg: (2340, 1654)
# Upper-left corner for CS_1040.jpg: X = 15.0, Y = 0.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_1040.tif
# Processing CS_1041.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_1041.jpg: (2340, 1654)
# Upper-left corner for CS_1041.jpg: X = 16.5, Y = 0.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_1041.tif
# Processing CS_1054.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_1054.jpg: (2340, 1654)
# Upper-left corner for CS_1054.jpg: X = 18.0, Y = 0.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_1054.tif
# Processing CS_1055.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_1055.jpg: (2340, 1654)
# Upper-left corner for CS_1055.jpg: X = 19.5, Y = 0.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_1055.tif
# Processing CS_11.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_11.jpg: (2340, 1654)
# Upper-left corner for CS_11.jpg: X = 21.0, Y = 0.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_11.tif
# Processing CS_12.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_12.jpg: (2340, 1654)
# Upper-left corner for CS_12.jpg: X = 22.5, Y = 0.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_12.tif
# Processing CS_122.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_122.jpg: (2340, 1654)
# Upper-left corner for CS_122.jpg: X = 24.0, Y = 0.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_122.tif
# Processing CS_126.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_126.jpg: (2340, 1654)
# Upper-left corner for CS_126.jpg: X = 25.5, Y = 0.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_126.tif
# Processing CS_127.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_127.jpg: (2340, 1654)
# Upper-left corner for CS_127.jpg: X = 27.0, Y = 0.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_127.tif
# Processing CS_128.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_128.jpg: (2340, 1654)
# Upper-left corner for CS_128.jpg: X = 28.5, Y = 0.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_128.tif
# Processing CS_14.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_14.jpg: (2340, 1654)
# Upper-left corner for CS_14.jpg: X = 30.0, Y = 0.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_14.tif
# Processing CS_145.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_145.jpg: (2340, 1654)
# Upper-left corner for CS_145.jpg: X = 31.5, Y = 0.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_145.tif
# Processing CS_15.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_15.jpg: (2340, 1654)
# Upper-left corner for CS_15.jpg: X = 33.0, Y = 0.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_15.tif
# Processing CS_150.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_150.jpg: (2340, 1654)
# Upper-left corner for CS_150.jpg: X = 34.5, Y = 0.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_150.tif
# Processing CS_151.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_151.jpg: (2340, 1654)
# Upper-left corner for CS_151.jpg: X = 36.0, Y = 0.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_151.tif
# Processing CS_152.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_152.jpg: (2340, 1654)
# Upper-left corner for CS_152.jpg: X = 0.0, Y = -1.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_152.tif
# Processing CS_153.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_153.jpg: (2340, 1654)
# Upper-left corner for CS_153.jpg: X = 1.5, Y = -1.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_153.tif
# Processing CS_154.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_154.jpg: (2340, 1654)
# Upper-left corner for CS_154.jpg: X = 3.0, Y = -1.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_154.tif
# Processing CS_170.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_170.jpg: (2340, 1654)
# Upper-left corner for CS_170.jpg: X = 4.5, Y = -1.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_170.tif
# Processing CS_176.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_176.jpg: (2340, 1654)
# Upper-left corner for CS_176.jpg: X = 6.0, Y = -1.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_176.tif
# Processing CS_178.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_178.jpg: (2340, 1654)
# Upper-left corner for CS_178.jpg: X = 7.5, Y = -1.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_178.tif
# Processing CS_179.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_179.jpg: (2340, 1654)
# Upper-left corner for CS_179.jpg: X = 9.0, Y = -1.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_179.tif
# Processing CS_181.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_181.jpg: (2340, 1654)
# Upper-left corner for CS_181.jpg: X = 10.5, Y = -1.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_181.tif
# Processing CS_197.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_197.jpg: (2340, 1654)
# Upper-left corner for CS_197.jpg: X = 12.0, Y = -1.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_197.tif
# Processing CS_207.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_207.jpg: (2340, 1654)
# Upper-left corner for CS_207.jpg: X = 13.5, Y = -1.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_207.tif
# Processing CS_208.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_208.jpg: (2340, 1654)
# Upper-left corner for CS_208.jpg: X = 15.0, Y = -1.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_208.tif
# Processing CS_209.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_209.jpg: (2340, 1654)
# Upper-left corner for CS_209.jpg: X = 16.5, Y = -1.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_209.tif
# Processing CS_210.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_210.jpg: (2340, 1654)
# Upper-left corner for CS_210.jpg: X = 18.0, Y = -1.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_210.tif
# Processing CS_2270.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_2270.jpg: (2340, 1654)
# Upper-left corner for CS_2270.jpg: X = 19.5, Y = -1.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_2270.tif
# Processing CS_2277.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_2277.jpg: (2340, 1654)
# Upper-left corner for CS_2277.jpg: X = 21.0, Y = -1.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_2277.tif
# Processing CS_2278.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_2278.jpg: (2340, 1654)
# Upper-left corner for CS_2278.jpg: X = 22.5, Y = -1.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_2278.tif
# Processing CS_237.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_237.jpg: (2340, 1654)
# Upper-left corner for CS_237.jpg: X = 24.0, Y = -1.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_237.tif
# Processing CS_238.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_238.jpg: (2340, 1654)
# Upper-left corner for CS_238.jpg: X = 25.5, Y = -1.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_238.tif
# Processing CS_239.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_239.jpg: (2340, 1654)
# Upper-left corner for CS_239.jpg: X = 27.0, Y = -1.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_239.tif
# Processing CS_240.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_240.jpg: (2340, 1654)
# Upper-left corner for CS_240.jpg: X = 28.5, Y = -1.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_240.tif
# Processing CS_268.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_268.jpg: (2340, 1654)
# Upper-left corner for CS_268.jpg: X = 30.0, Y = -1.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_268.tif
# Processing CS_269.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_269.jpg: (2340, 1654)
# Upper-left corner for CS_269.jpg: X = 31.5, Y = -1.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_269.tif
# Processing CS_271.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_271.jpg: (2340, 1654)
# Upper-left corner for CS_271.jpg: X = 33.0, Y = -1.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_271.tif
# Processing CS_299.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_299.jpg: (2340, 1654)
# Upper-left corner for CS_299.jpg: X = 34.5, Y = -1.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_299.tif
# Processing CS_3.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_3.jpg: (2340, 1654)
# Upper-left corner for CS_3.jpg: X = 36.0, Y = -1.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_3.tif
# Processing CS_300.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_300.jpg: (2340, 1654)
# Upper-left corner for CS_300.jpg: X = 0.0, Y = -3.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_300.tif
# Processing CS_301.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_301.jpg: (2340, 1654)
# Upper-left corner for CS_301.jpg: X = 1.5, Y = -3.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_301.tif
# Processing CS_330.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_330.jpg: (2340, 1654)
# Upper-left corner for CS_330.jpg: X = 3.0, Y = -3.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_330.tif
# Processing CS_331.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_331.jpg: (2340, 1654)
# Upper-left corner for CS_331.jpg: X = 4.5, Y = -3.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_331.tif
# Processing CS_362.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_362.jpg: (2340, 1654)
# Upper-left corner for CS_362.jpg: X = 6.0, Y = -3.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_362.tif
# Processing CS_363.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_363.jpg: (2340, 1654)
# Upper-left corner for CS_363.jpg: X = 7.5, Y = -3.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_363.tif
# Processing CS_368.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_368.jpg: (2340, 1654)
# Upper-left corner for CS_368.jpg: X = 9.0, Y = -3.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_368.tif
# Processing CS_392.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_392.jpg: (2340, 1654)
# Upper-left corner for CS_392.jpg: X = 10.5, Y = -3.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_392.tif
# Processing CS_4.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_4.jpg: (2340, 1654)
# Upper-left corner for CS_4.jpg: X = 12.0, Y = -3.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_4.tif
# Processing CS_406.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_406.jpg: (2340, 1654)
# Upper-left corner for CS_406.jpg: X = 13.5, Y = -3.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_406.tif
# Processing CS_437.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_437.jpg: (2340, 1654)
# Upper-left corner for CS_437.jpg: X = 15.0, Y = -3.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_437.tif
# Processing CS_438.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_438.jpg: (2340, 1654)
# Upper-left corner for CS_438.jpg: X = 16.5, Y = -3.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_438.tif
# Processing CS_439.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_439.jpg: (2340, 1654)
# Upper-left corner for CS_439.jpg: X = 18.0, Y = -3.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_439.tif
# Processing CS_468.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_468.jpg: (2340, 1654)
# Upper-left corner for CS_468.jpg: X = 19.5, Y = -3.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_468.tif
# Processing CS_469.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_469.jpg: (2340, 1654)
# Upper-left corner for CS_469.jpg: X = 21.0, Y = -3.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_469.tif
# Processing CS_498.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_498.jpg: (2340, 1654)
# Upper-left corner for CS_498.jpg: X = 22.5, Y = -3.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_498.tif
# Processing CS_5.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_5.jpg: (2340, 1654)
# Upper-left corner for CS_5.jpg: X = 24.0, Y = -3.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_5.tif
# Processing CS_500.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_500.jpg: (2340, 1654)
# Upper-left corner for CS_500.jpg: X = 25.5, Y = -3.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_500.tif
# Processing CS_532.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_532.jpg: (2340, 1654)
# Upper-left corner for CS_532.jpg: X = 27.0, Y = -3.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_532.tif
# Processing CS_533.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_533.jpg: (2340, 1654)
# Upper-left corner for CS_533.jpg: X = 28.5, Y = -3.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_533.tif
# Processing CS_55.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_55.jpg: (2340, 1654)
# Upper-left corner for CS_55.jpg: X = 30.0, Y = -3.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_55.tif
# Processing CS_566.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_566.jpg: (2340, 1654)
# Upper-left corner for CS_566.jpg: X = 31.5, Y = -3.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_566.tif
# Processing CS_567.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_567.jpg: (2340, 1654)
# Upper-left corner for CS_567.jpg: X = 33.0, Y = -3.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_567.tif
# Processing CS_568.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_568.jpg: (2340, 1654)
# Upper-left corner for CS_568.jpg: X = 34.5, Y = -3.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_568.tif
# Processing CS_598.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_598.jpg: (2340, 1654)
# Upper-left corner for CS_598.jpg: X = 36.0, Y = -3.0
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_598.tif
# Processing CS_599.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_599.jpg: (2340, 1654)
# Upper-left corner for CS_599.jpg: X = 0.0, Y = -4.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_599.tif
# Processing CS_6.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_6.jpg: (2340, 1654)
# Upper-left corner for CS_6.jpg: X = 1.5, Y = -4.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_6.tif
# Processing CS_629.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_629.jpg: (2340, 1654)
# Upper-left corner for CS_629.jpg: X = 3.0, Y = -4.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_629.tif
# Processing CS_630.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_630.jpg: (2340, 1654)
# Upper-left corner for CS_630.jpg: X = 4.5, Y = -4.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_630.tif
# Processing CS_658.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_658.jpg: (2340, 1654)
# Upper-left corner for CS_658.jpg: X = 6.0, Y = -4.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_658.tif
# Processing CS_659.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_659.jpg: (2340, 1654)
# Upper-left corner for CS_659.jpg: X = 7.5, Y = -4.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_659.tif
# Processing CS_660.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_660.jpg: (2340, 1654)
# Upper-left corner for CS_660.jpg: X = 9.0, Y = -4.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_660.tif
# Processing CS_687.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_687.jpg: (2340, 1654)
# Upper-left corner for CS_687.jpg: X = 10.5, Y = -4.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_687.tif
# Processing CS_688.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_688.jpg: (2340, 1654)
# Upper-left corner for CS_688.jpg: X = 12.0, Y = -4.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_688.tif
# Processing CS_689.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_689.jpg: (2340, 1654)
# Upper-left corner for CS_689.jpg: X = 13.5, Y = -4.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_689.tif
# Processing CS_715.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_715.jpg: (2340, 1654)
# Upper-left corner for CS_715.jpg: X = 15.0, Y = -4.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_715.tif
# Processing CS_716.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_716.jpg: (2340, 1654)
# Upper-left corner for CS_716.jpg: X = 16.5, Y = -4.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_716.tif
# Processing CS_717.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_717.jpg: (2340, 1654)
# Upper-left corner for CS_717.jpg: X = 18.0, Y = -4.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_717.tif
# Processing CS_743.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_743.jpg: (2340, 1654)
# Upper-left corner for CS_743.jpg: X = 19.5, Y = -4.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_743.tif
# Processing CS_77.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_77.jpg: (2340, 1654)
# Upper-left corner for CS_77.jpg: X = 21.0, Y = -4.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_77.tif
# Processing CS_8.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_8.jpg: (2340, 1654)
# Upper-left corner for CS_8.jpg: X = 22.5, Y = -4.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_8.tif
# Processing CS_80.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_80.jpg: (2340, 1654)
# Upper-left corner for CS_80.jpg: X = 24.0, Y = -4.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_80.tif
# Processing CS_9.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_9.jpg: (2340, 1654)
# Upper-left corner for CS_9.jpg: X = 25.5, Y = -4.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_9.tif
# Processing CS_966.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_966.jpg: (2340, 1654)
# Upper-left corner for CS_966.jpg: X = 27.0, Y = -4.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_966.tif
# Processing CS_967.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_967.jpg: (2340, 1654)
# Upper-left corner for CS_967.jpg: X = 28.5, Y = -4.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_967.tif
# Processing CS_968.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_968.jpg: (2340, 1654)
# Upper-left corner for CS_968.jpg: X = 30.0, Y = -4.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_968.tif
# Processing CS_983.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_983.jpg: (2340, 1654)
# Upper-left corner for CS_983.jpg: X = 31.5, Y = -4.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_983.tif
# Processing CS_984.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_984.jpg: (2340, 1654)
# Upper-left corner for CS_984.jpg: X = 33.0, Y = -4.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_984.tif
# Processing CS_985.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_985.jpg: (2340, 1654)
# Upper-left corner for CS_985.jpg: X = 34.5, Y = -4.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_985.tif
# Processing CS_998.jpg with original dimensions: (2338, 1653)
# Resized dimensions for CS_998.jpg: (2340, 1654)
# Upper-left corner for CS_998.jpg: X = 36.0, Y = -4.5
# GeoTIFF saved: C:\\Users\\filip\\Documents\\ARC_GIS_Dukovany\\test_rectified\CS_998.tif
# All images rectified in 5.64 seconds.
