# %%
"""
Script 4: LayerAnnotator

Description:
This script provides a semi-automated interface to manually assign layer numbers to polygon geometries
extracted from georeferenced stratigraphic section drawings. It overlays each polygon on its corresponding
section drawing (based on template matching and ROI extraction), and allows the user to:

- Enter the correct layer number (`Layer_No`)
- Assign the `Section_ID` based on the filename
- Mark all layers in a section as valid or erroneous (`Error` column)

To use this script correctly, the user must define user settings (see below)

The script uses a pre-existing shapefile that already contains the polygons and a `Raster` column linking each polygon
to its source raster image. Visual verification of geometry placement is done through matplotlib overlays.

Notes:
- The template must match the scale bar appearance and size used in the dataset.
- Ensure the shapefile contains or allows adding columns: `Layer_No`, `Section_ID`, `Error`.
- Polygons marked with `Layer_No = 0` are removed from the final shapefile upon saving.
"""
import os
import time
import cv2
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Polygon
import rasterio
from rasterio.plot import reshape_as_image

# ---------------------------------------------
# USER SETTINGS (EDIT BEFORE RUNNING)
# ---------------------------------------------
input_folder = r"C:\path_to_imput_folder" # Path to the folder containing the rectified GeoTIFFs
shapefile_path = r"C:\path_to_LAYER.shp" #Path to the shapefile with polygon geometries and the "Raster" column
template_path = r"C:\path_to_template" #Image of the 1m scale bar used to locate the drawing area for ROI extraction

roi_width = 300 # This defines how wide the cropped drawing area will be. Adjust based on the form layout.
scale_template_resize_factor = 2.35 # Must match the scale appearance in the rectified drawings. Try adjusting if template matching fails.
roi_x_offset_pixels = 0  # Optional horizontal offset (in pixels) applied to shift the ROI position further to the right of the scale bar. Use if the ROI is misaligned due to form variation.
# ---------------------------------------------
# FUNCTIONS
# ---------------------------------------------
def template_matching(img, template_path):
    """Locate the position of the scale bar in a raster image using template matching"""
    template = cv2.imread(template_path, 0)
    template = cv2.resize(template, (
        int(template.shape[1] * scale_template_resize_factor),
        int(template.shape[0] * scale_template_resize_factor)))
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    result = cv2.matchTemplate(img_gray, template, cv2.TM_CCOEFF_NORMED)
    _, _, _, max_loc = cv2.minMaxLoc(result)
    return max_loc, template.shape[::-1]

def extract_roi(img, scale_loc, scale_size, roi_width):
    """Extract the Region of Interest (ROI) to the right of the scale bar."""
    x, y = scale_loc
    t_w, t_h = scale_size
    roi_x = x + t_w + roi_x_offset_pixels
    roi_y = y
    roi = img[roi_y:roi_y + t_h, roi_x:roi_x + roi_width]
    return roi, (roi_x, roi_y, t_h, roi_width)

def overlay_geometry_on_roi(roi, geom, transform, roi_origin):
    """Plot a shapely polygon geometry overlaid on the ROI image for visual inspection."""
    fig, ax = plt.subplots(figsize=(5, 6))
    ax.imshow(cv2.cvtColor(roi, cv2.COLOR_BGR2RGB))

    # Transform polygon coordinates to image space
    inv_transform = ~transform
    roi_x, roi_y, _, _ = roi_origin

    if isinstance(geom, Polygon):
        x, y = geom.exterior.coords.xy
        px = []
        py = []
        for xi, yi in zip(x, y):
            col, row = inv_transform * (xi, yi)
            px.append(col - roi_x)
            py.append(row - roi_y)
        ax.plot(px, py, color='red', linewidth=2)

    ax.axis('off')
    plt.tight_layout()
    plt.show()
# ---------------------------------------------
# MAIN PROCESS
# ---------------------------------------------
def main():
    start_time = time.time()
#    layer_records = []

    gdf = gpd.read_file(shapefile_path)

    # Add columns if not exist
    for col in ["Layer_No", "Section_ID", "Error"]:
        if col not in gdf.columns:
            gdf[col] = None

    rasters = gdf["Raster"].unique()

    for filename in sorted(os.listdir(input_folder)):
        if not filename.endswith(".tif"):
            continue

        raster_name = os.path.splitext(filename)[0]
        matching_polys = gdf[gdf["Raster"] == raster_name]

        if matching_polys.empty:
            print(f"⚠️ No polygons found for raster: {raster_name}")
            continue

        print(f"🔍 Processing {raster_name} with {len(matching_polys)} layers")

        raster_path = os.path.join(input_folder, filename)
        
        with rasterio.open(raster_path) as src:
            transform = src.transform
            img = reshape_as_image(src.read())
            if img.shape[2] == 1:
                img = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)

        scale_loc, scale_size = template_matching(img, template_path)
        roi, roi_origin = extract_roi(img, scale_loc, scale_size, roi_width)

        for idx in matching_polys.index:
            polygon = gdf.loc[idx, "geometry"]
            overlay_geometry_on_roi(roi, polygon, transform, roi_origin)

            while True:
                layer_input = input("Layer number (or press Enter to skip): ").strip()
                if layer_input == "":
                    gdf.loc[idx, "Layer_No"] = 0
                    break
                elif layer_input.isdigit():
                    gdf.loc[idx, "Layer_No"] = int(layer_input)
                    break
                else:
                    print("Invalid input. Please enter a number.")

            section_id = ''.join(filter(str.isdigit, raster_name))
            gdf.loc[idx, "Section_ID"] = section_id

        confirm = input(f"✅ Confirm {raster_name} (Enter = OK, 'e' = mark all as error): ").strip().lower()
        if confirm == 'e':
            gdf.loc[gdf["Raster"] == raster_name, "Error"] = "Error"
        else:
            gdf.loc[gdf["Raster"] == raster_name, "Error"] = "OK"

    # Remove polygons with Layer_No = 0
    gdf = gdf[gdf["Layer_No"] != 0]

    # Save changes
    gdf.to_file(shapefile_path, driver="ESRI Shapefile")
    elapsed = time.time() - start_time
    print(f"✅ Updated and saved shapefile: {shapefile_path}")
    print(f"⏱️ Elapsed time: {elapsed:.2f} seconds")

if __name__ == "__main__":
    main()
# Out:
# 🔍 Processing CS_10 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  106
# ✅ Confirm CS_10 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_100 with 1 layers
# Layer number (or press Enter to skip):  100
# ✅ Confirm CS_100 (Enter = OK, 'e' = mark all as error):  e
# 🔍 Processing CS_1013 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  109
# ✅ Confirm CS_1013 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_1014 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  104
# ✅ Confirm CS_1014 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_1015 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  106
# ✅ Confirm CS_1015 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_1026 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_1026 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_1027 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  111
# ✅ Confirm CS_1027 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_1028 with 1 layers
# Layer number (or press Enter to skip):  100
# ✅ Confirm CS_1028 (Enter = OK, 'e' = mark all as error):  e
# 🔍 Processing CS_103 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_103 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_104 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  103
# ✅ Confirm CS_104 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_1040 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_1040 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_1041 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_1041 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_1054 with 1 layers
# Layer number (or press Enter to skip):  100
# ✅ Confirm CS_1054 (Enter = OK, 'e' = mark all as error):  e
# 🔍 Processing CS_1055 with 1 layers
# Layer number (or press Enter to skip):  100
# ✅ Confirm CS_1055 (Enter = OK, 'e' = mark all as error):  e
# 🔍 Processing CS_11 with 1 layers
# Layer number (or press Enter to skip):  100
# ✅ Confirm CS_11 (Enter = OK, 'e' = mark all as error):  e
# 🔍 Processing CS_12 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  106
# ✅ Confirm CS_12 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_122 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  110
# ✅ Confirm CS_122 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_126 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_126 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_127 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_127 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_128 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  103
# ✅ Confirm CS_128 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_14 with 3 layers
# Layer number (or press Enter to skip):  0
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_14 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_145 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  133
# ✅ Confirm CS_145 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_15 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_15 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_150 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  104
# ✅ Confirm CS_150 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_151 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_151 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_152 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_152 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_153 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_153 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_154 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_154 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_170 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  110
# ✅ Confirm CS_170 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_176 with 1 layers
# Layer number (or press Enter to skip):  100
# ✅ Confirm CS_176 (Enter = OK, 'e' = mark all as error):  e
# 🔍 Processing CS_178 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_178 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_179 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  111
# ✅ Confirm CS_179 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_181 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_181 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_197 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  103
# ✅ Confirm CS_197 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_207 with 3 layers
# Layer number (or press Enter to skip):  0
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  111
# ✅ Confirm CS_207 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_208 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  133
# ✅ Confirm CS_208 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_209 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  104
# ✅ Confirm CS_209 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_210 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  104
# ✅ Confirm CS_210 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_2270 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_2270 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_2277 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_2277 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_2278 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  103
# ✅ Confirm CS_2278 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_237 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  109
# ✅ Confirm CS_237 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_238 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  104
# ✅ Confirm CS_238 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_239 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_239 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_240 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_240 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_268 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_268 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_269 with 3 layers
# Layer number (or press Enter to skip):  0
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_269 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_271 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  106
# ✅ Confirm CS_271 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_299 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_299 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_3 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  104
# ✅ Confirm CS_3 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_300 with 1 layers
# Layer number (or press Enter to skip):  100
# ✅ Confirm CS_300 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_301 with 1 layers
# Layer number (or press Enter to skip):  100
# ✅ Confirm CS_301 (Enter = OK, 'e' = mark all as error):  e
# 🔍 Processing CS_330 with 1 layers
# Layer number (or press Enter to skip):  100
# ✅ Confirm CS_330 (Enter = OK, 'e' = mark all as error):  e
# 🔍 Processing CS_331 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_331 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_362 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_362 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_363 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_363 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_368 with 1 layers
# Layer number (or press Enter to skip):  100
# ✅ Confirm CS_368 (Enter = OK, 'e' = mark all as error):  e
# 🔍 Processing CS_392 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_392 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_4 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  109
# ✅ Confirm CS_4 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_406 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_406 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_437 with 1 layers
# Layer number (or press Enter to skip):  100
# ✅ Confirm CS_437 (Enter = OK, 'e' = mark all as error):  e
# 🔍 Processing CS_438 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  103
# ✅ Confirm CS_438 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_439 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  104
# ✅ Confirm CS_439 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_468 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_468 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_469 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_469 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_498 with 1 layers
# Layer number (or press Enter to skip):  100
# ✅ Confirm CS_498 (Enter = OK, 'e' = mark all as error):  e
# 🔍 Processing CS_5 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  109
# ✅ Confirm CS_5 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_500 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  103
# ✅ Confirm CS_500 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_532 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  103
# ✅ Confirm CS_532 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_533 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  104
# ✅ Confirm CS_533 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_55 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  110
# ✅ Confirm CS_55 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_566 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  103
# ✅ Confirm CS_566 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_567 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  104
# ✅ Confirm CS_567 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_568 with 1 layers
# Layer number (or press Enter to skip):  100
# ✅ Confirm CS_568 (Enter = OK, 'e' = mark all as error):  e
# 🔍 Processing CS_598 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  104
# ✅ Confirm CS_598 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_599 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  106
# ✅ Confirm CS_599 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_6 with 3 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  109
# Layer number (or press Enter to skip):
# ✅ Confirm CS_6 (Enter = OK, 'e' = mark all as error):  e
# 🔍 Processing CS_629 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_629 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_630 with 1 layers
# Layer number (or press Enter to skip):  100
# ✅ Confirm CS_630 (Enter = OK, 'e' = mark all as error):  e
# 🔍 Processing CS_658 with 3 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  0
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_658 (Enter = OK, 'e' = mark all as error):  e
# 🔍 Processing CS_659 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_659 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_660 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  103
# ✅ Confirm CS_660 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_687 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  103
# ✅ Confirm CS_687 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_688 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  104
# ✅ Confirm CS_688 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_689 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  106
# ✅ Confirm CS_689 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_715 with 3 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  0
# Layer number (or press Enter to skip):  102
# ✅ Confirm CS_715 (Enter = OK, 'e' = mark all as error):  e
# 🔍 Processing CS_716 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  104
# ✅ Confirm CS_716 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_717 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  110
# ✅ Confirm CS_717 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_743 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  104
# ✅ Confirm CS_743 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_77 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  110
# ✅ Confirm CS_77 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_8 with 3 layers
# Layer number (or press Enter to skip):  0
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  106
# ✅ Confirm CS_8 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_80 with 1 layers
# Layer number (or press Enter to skip):  100
# ✅ Confirm CS_80 (Enter = OK, 'e' = mark all as error):  e
# 🔍 Processing CS_9 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  106
# ✅ Confirm CS_9 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_966 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  104
# ✅ Confirm CS_966 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_967 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  109
# ✅ Confirm CS_967 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_968 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  110
# ✅ Confirm CS_968 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_983 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  110
# ✅ Confirm CS_983 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_984 with 3 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  0
# Layer number (or press Enter to skip):  110
# ✅ Confirm CS_984 (Enter = OK, 'e' = mark all as error):  e
# 🔍 Processing CS_985 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  110
# ✅ Confirm CS_985 (Enter = OK, 'e' = mark all as error):
# 🔍 Processing CS_998 with 2 layers
# Layer number (or press Enter to skip):  100
# Layer number (or press Enter to skip):  104
# ✅ Confirm CS_998 (Enter = OK, 'e' = mark all as error):
# ✅ Updated and saved shapefile: C:\Users\filip\Documents\ARC_GIS_Dukovany\shp_test\VRSTVA.shp
# ⏱️ Elapsed time: 645.14 seconds
